# %% [markdown]
# # Exercise 3 — UMAP (≈10 minutes)
#
# Dataset: `day5_example.csv`.
#
# 1. Load the dataset.
# 2. Run **UMAP** with the two settings:
#    * `min_dist = 2` and `n_neighbors = 1`
#    * `min_dist = 0.1` and `n_neighbors = 10`
# 3. Plot the embeddings with seaborn, **color by group**.

# %%
# 1. Load the dataset

# %%
# 2. UMAP with two sets (on standardized features)

# HINT: import umap
# HINT: don't foreget to scale the data

# %%
# 3. Plot embeddings (color by group)
