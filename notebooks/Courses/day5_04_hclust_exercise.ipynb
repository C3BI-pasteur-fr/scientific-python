# %% [markdown]
# # Exercise 4 — Hierarchical clustering and Silhouette
#
# Dataset: **`day5_example.csv`**
#
# ## Tasks
# 1. Load the dataset `day5_example.csv`.
# 2. Plot the **heatmap with dendrograms** using `seaborn.clustermap`, with the `group` shown on the side.
# 3. Compute the **silhouette plots** for **k = 2, 3, 4, 5** and select the best value based on the average silhouette score.

# %%
# 1. Load dataset

# %%
# 2. Heatmap + dendrograms (with group colors on the side)

# %%
# 3. Silhouette plots for k = 2, 3, 4, 5
