# %% [markdown]
# # Exercise 2 — Principal Component Analysis (≈10 minutes)
#
# Dataset: **`day5_example.csv`** (place it where you can find it).
#
# 1. Load the dataset `day5_example.csv`.
# 2. Run a **standardized PCA** on the numeric variables.
# 3. Plot the **scree plot** and decide how many dimensions to keep.
# 4. Plot the **individual map** (scores on PC1–PC2), **color by group**.
# 5. Plot the **correlation circle** for the variables.
# 6. Conclude.

# %%
# 1. Load dataset

# %%
# 2. Standardized PCA on numeric variables

# HINT: sklearn.preprocessing.StandardScaler
# HINT: sklearn.decomposition.PCA

# %%
# 3. Scree plot

# HINT: explained_variance_ratio_

# %%
# 4. Individual map (PC1 vs PC2), color groups

# %%
# 5. Correlation circle

# %% [markdown]
# ## 6. Conclusion
