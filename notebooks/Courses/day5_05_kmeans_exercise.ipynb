# %% [markdown]
# # Exercise 5 — k-means and Rand Index
#
# Dataset: `day5_example.csv`.
#
# 1. Load the dataset.
# 2. Run **k-means** on the numeric data with **k = 2**.
# 3. Compute the **Rand Index** between the k-means partition and the column `group`.

# %%
# 1. Load dataset

# %%
# 2. k-means with k=2 (standardize first)

# HINT: standardize first!
# HINT: sklearn.cluster.KMeans

# %%
# 3. Rand Index vs `group`

# HINT: sklearn.metrics.rand_score
