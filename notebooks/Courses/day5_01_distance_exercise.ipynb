# %% [markdown]
# # Exercise: Distances and Heatmaps (≈10 minutes)
#
# Dataset: **`example_day5.csv`** (place it where it's easy to find it!).
#
# 1. Load the dataset `example_day5.csv`.
# 2. Compute the **Euclidean distance** between the **observations** (rows).
# 3. Make a **heatmap** of this distance matrix.
# 4. Compute the **correlation distance** between the **variables** (columns).
# 5. Make a **heatmap** of this distance matrix.

# %%
# 1. Load the dataset

# Hint: pandas.read_csv

# %%
# 2. Euclidean distance between observations (rows)

# HINT: sklearn.metrics.pairwise_distances

# %%
# 3. Heatmap of Euclidean distances

# HINT: seaborn.heatmap

# %%
# 4. Correlation distance between variables (columns)

# HINT: correlation distance = 1 - correlation

# %%
# 5. Heatmap of correlation distance (variables)
